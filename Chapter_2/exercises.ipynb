# %% [markdown]
# # Exercises

# %%
x = y = 1
print(x, y)

x = 5; y = 10; print(x * y) # semi colon acts as a separator

my_number = 10.
import math; print(math.pi)
# Out:
# 1 1
# 50
# 3.141592653589793

# %%
import math
radius = 5
volume = (4 / 3) * math.pi * (radius ** 3)
print(f"The volume of {radius} cm is {volume:3f} cm")
# Out:
# The volume of 5 cm is 523.598776 cm

# %%
x = 545
(math.cos(x)) ** 2 + (math.sin(x)) ** 2
# Out:
# 1.0

# %%
import math

print(math.e ** 2)
print(math.pow(math.e ,2))
print(math.exp(math.e))
# Out:
# 7.3890560989306495
# 7.3890560989306495
# 15.154262241479262
