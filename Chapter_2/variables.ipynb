# %% [markdown]
# # 2. Variables and Statements

# %% [markdown]
# ## 2.1. Variables

# %%
# Name that refers to a value. 
n = 17

# Floating point
pi = 3.141592653589793

# String
message = "And now for something different"

print(message)

print(n + 25)

print(2 * pi)

print(round(pi))

len(message)
# Out:
# And now for something different
# 42
# 6.283185307179586
# 3
# 31

# %% [markdown]
# ## 2.2 State diagrams
# - To represent a variable on paper, you can write the name and point its value with an arrow

# %% [markdown]
# ## 2.3. Variable Names
# ```python
# million! = 100000
#
# 76trombones = "big parade"
#
# class = "Self-Defense Against Fresh Fruit"
# ```
# - Each one will provide an error because the namings come from the Python's keywords list

# %% [markdown]
# ## 2.4. The import statement

# %%
import math

print(math.pi)

print(math.sqrt(25))

print(math.pow(5,2))
# Out:
# 3.141592653589793
# 5.0
# 25.0

# %% [markdown]
# ## 2.5. Expressions and statements

# %%
print(19 + n + round(math.pi) *2)

n = 17

# Import statement imports a module that contains variables and functions we can use it
# But does not have a visible effect
# Out:
# 42

# %% [markdown]
# ## 2.6. Print Function

# %%
print("Hello World!")

# %% [markdown]
# ## 2.7. Arguments

# %%
int("101")

print(math,pow(5, 2))

int("101", 2) # Base of the number

print("Any", "number", "of", "arguments") 

float("123.0", 2) # Type error

math.pow(2)

math.sqrt("123")

# %% [markdown]
# ## 2.8. Comments

# %%
# number of seconds in 42:42
seconds = 42 * 60 + 42

miles = 10 / 1.61 # 10 kilometers in miles

# Good variable names can reduce the need of comments

# %% [markdown]
# ## 2.9. Debugging
#
# - There are multiple errors that can occur
#
# 1. Syntax error: "Syntax refers to the structure of a program and its rules"
# 2. Runtime error: "If there is no syntax error, it can start running but python displays an error message and stops
# 3. Semantic error: tricky because it runs without generating error messages. Looking at the output might help

# %% [markdown]
# ## Ask a virtual assistant

# %%
# Built-in functions in python 

test = "Testing functions"
test_= (2,3)

# Essential getting Data In and Out
print() # Displays info
hello = input() # Pauses program, letting user to type something always returning a string
print(hello) 
type(test) # Tells the data type of the variable
help() # Invokes built-in help system

# Converters (Data Types)
int() 
float()
str() 
list()
dict()
set()

# Number Crunchers
len(test)
sum(test_)
min(test_)
max(test_)
abs(1)

# Loop Companions
# When writing loops these become the best use
range(2)
enumerate(test_)
sorted(test)
zip(test, test_)
# Out:
# Salut
# Welcome to Python 3.11's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.11/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
# ...
